# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('icecreame.jpeg')
img2 = cv2.imread('cake.jpeg')
img2 = img2[150:150+225, 150:150+225,:]

# %%
img.shape , img2.shape
# Out:
# ((225, 225, 3), (288, 288, 3))

# %%
plt.imshow(img)

# %%
def showing(im):
    plt.imshow(im[:,:,::-1])
    plt.show


def imshow(im):
     cv2.imshow('Preview',im)
     cv2.waitKey(0)
     cv2.destroyAllWindows()

# %%
showing(img)

# %%
imshow(img)

# %%
# !pip install numpy --upgrade
# Out:
# Requirement already satisfied: numpy in c:\users\hansa\appdata\local\programs\python\python310\lib\site-packages (1.24.3)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hansa\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hansa\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hansa\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hansa\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hansa\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hansa\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
imshow(img2)

# %%
import cv2

# %%
img.shape
# Out:
# (225, 225, 3)

# %%
img2.shape
# Out:
# (225, 225, 3)

# %%
added = cv2.add(img , img2)
showing(added)
